# %% [markdown]
# <a href="https://colab.research.google.com/github/jsanothernpc/Ayushman_4NI23CI021-ML2/blob/main/ML2FirstLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_dataset.csv")

# %%
df.head()
#display the first five rows
# Out:
#    Student_ID   Age  Gender  StudyHours  Attendance  Marks Result
# 0           1  18.0    Male         3.0        85.0   72.0   Pass
# 1           2  19.0  Female         5.0        92.0   88.0   Pass
# 2           3  18.0    Male         2.0        70.0   55.0   Pass
# 3           4  20.0  Female         6.0        95.0   91.0   Pass
# 4           5  19.0    Male         1.0        60.0   42.0   Fail

# %%
df.tail()
#display the last five rows
# Out:
#    Student_ID   Age  Gender  StudyHours  Attendance  Marks Result
# 5           6  18.0  Female         NaN        88.0   76.0   Pass
# 6           7   NaN    Male         4.0         NaN   68.0   Pass
# 7           8  21.0  Female         2.0        65.0    NaN   Fail
# 8           9  19.0    Male         1.0        60.0   42.0   Fail
# 9          10  20.0     NaN         5.0        90.0   84.0   Pass

# %%
df.shape
# Out:
# (10, 7)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'StudyHours', 'Attendance', 'Marks',
#        'Result'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Student_ID      int64
# Age           float64
# Gender         object
# StudyHours    float64
# Attendance    float64
# Marks         float64
# Result         object
# dtype: object

# %%
#missing value
df.isnull().sum()
# Out:
# Student_ID    0
# Age           1
# Gender        1
# StudyHours    1
# Attendance    1
# Marks         1
# Result        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Age           0
# Gender        0
# StudyHours    0
# Attendance    0
# Marks         0
# Result        0
# dtype: int64

# %%
df.shape
# Out:
# (6, 7)

# %%
print('Reloading dataset to handle missing values...')
df = pd.read_csv('student_dataset.csv')
display(df.head())
# Out:
# Reloading dataset to handle missing values...
#    Student_ID   Age  Gender  StudyHours  Attendance  Marks Result
# 0           1  18.0    Male         3.0        85.0   72.0   Pass
# 1           2  19.0  Female         5.0        92.0   88.0   Pass
# 2           3  18.0    Male         2.0        70.0   55.0   Pass
# 3           4  20.0  Female         6.0        95.0   91.0   Pass
# 4           5  19.0    Male         1.0        60.0   42.0   Fail

# %%
# Fill missing numerical values with the median
for col in ['Age', 'StudyHours', 'Attendance', 'Marks']:
    if col in df.columns:
        df[col].fillna(df[col].median(), inplace=True)

# Fill missing categorical values with the mode
for col in ['Gender']:
    if col in df.columns:
        df[col].fillna(df[col].mode()[0], inplace=True)

print('Missing values after filling:')
display(df.isnull().sum())

# %%
print('DataFrame after filling missing values:')
display(df.head())
# Out:
# DataFrame after filling missing values:
#    Student_ID   Age  Gender  StudyHours  Attendance  Marks Result
# 0           1  18.0    Male         3.0        85.0   72.0   Pass
# 1           2  19.0  Female         5.0        92.0   88.0   Pass
# 2           3  18.0    Male         2.0        70.0   55.0   Pass
# 3           4  20.0  Female         6.0        95.0   91.0   Pass
# 4           5  19.0    Male         1.0        60.0   42.0   Fail

# %%
print(df)
# Out:
#    Student_ID        Age  Gender  StudyHours  Attendance      Marks Result
# 0           1  18.000000    Male    3.000000   85.000000  72.000000   Pass
# 1           2  19.000000  Female    5.000000   92.000000  88.000000   Pass
# 2           3  18.000000    Male    2.000000   70.000000  55.000000   Pass
# 3           4  20.000000  Female    6.000000   95.000000  91.000000   Pass
# 4           5  19.000000    Male    1.000000   60.000000  42.000000   Fail
# 5           6  18.000000  Female    3.222222   88.000000  76.000000   Pass
# 6           7  19.111111    Male    4.000000   78.333333  68.000000   Pass
# 7           8  21.000000  Female    2.000000   65.000000  68.666667   Fail
# 8           9  19.000000    Male    1.000000   60.000000  42.000000   Fail
# 9          10  20.000000    Male    5.000000   90.000000  84.000000   Pass

# %%
df['Marks'].fillna(df['Marks'].median(),inplace=True)
# Out:
# /tmp/ipykernel_907/1816101993.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(df['Marks'].median(),inplace=True)

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Student_ID        Age  StudyHours  Attendance      Marks
# count    10.00000  10.000000   10.000000   10.000000  10.000000
# mean      5.50000  19.111111    3.222222   78.333333  68.666667
# std       3.02765   0.993808    1.749780   13.572849  17.581556
# min       1.00000  18.000000    1.000000   60.000000  42.000000
# 25%       3.25000  18.250000    2.000000   66.250000  58.250000
# 50%       5.50000  19.000000    3.111111   81.666667  70.333333
# 75%       7.75000  19.777778    4.750000   89.500000  82.000000
# max      10.00000  21.000000    6.000000   95.000000  91.000000

# %%
plt.hist(df['Marks'],bins=10)
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.title('Marks Distribution')
plt.show()

# %%
plt.boxplot(df['Marks'])
plt.ylabel('Marks')
plt.title('Boxplot of Marks')
plt.show()

# %%
corr=df.corr(numeric_only=True)
print(corr)
# Out:
#             Student_ID       Age  StudyHours  Attendance     Marks
# Student_ID    1.000000  0.541603   -0.144483   -0.305534 -0.188557
# Age           0.541603  1.000000    0.232707   -0.052169  0.258134
# StudyHours   -0.144483  0.232707    1.000000    0.925469  0.930492
# Attendance   -0.305534 -0.052169    0.925469    1.000000  0.931286
# Marks        -0.188557  0.258134    0.930492    0.931286  1.000000

# %%
df.shape
# Out:
# (10, 7)
